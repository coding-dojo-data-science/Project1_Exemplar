# %% [markdown]
# <a href="https://colab.research.google.com/github/coding-dojo-data-science/Project1_Exemplar/blob/main/Data_Science_Salary_Insights_Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Salary Insights

# %% [markdown]
# Sherlin Whaley

# %% [markdown]
# ## Loading Data

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Exploratory Visuals

# %% [markdown]
# ## Explanatory Visuals
